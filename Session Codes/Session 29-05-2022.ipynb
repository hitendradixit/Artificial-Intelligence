# %%
import cv2

# %%
img = cv2.imread(r'cat.jpg',1)
#This is using for display the image  
cv2.imshow('image',img)
cv2.waitKey(1200) # This is necessary to be required so that the image doesn't close immediately.  
#It will run continuously until the key press.  
cv2.destroyAllWindows()

# %%
img = cv2.imread(r'cat.jpg',1)
# save image  
status = cv2.imwrite(r'cat2.jpeg',  img)
print("Image written to file-system : ", status)
# Out:
# Image written to file-system :  True

# %%
import numpy as np

# %%
img = cv2.imread('cat.jpg',1)
pixel = img[100,100]
print(pixel)
# Out:
# [243 239 234]

# %% [markdown]
# Accessing Image Properties

# %%
img = cv2.imread(r'cat.jpg',1)
#height, width, number of channels in image
height = img.shape[0]
width = img.shape[1]
channels = img.shape[2]
size1 = img.size
print(f"Height : {height}")
print(f"Width : {width}")
print(f"channels : {channels}")
print(f"size : {size1}")
# Out:
# Height : 3560
# Width : 5360
# channels : 3
# size : 57244800

# %% [markdown]
# Splitting and merging

# %%
img = cv2.imread(r'Sample1.jpg',1)
b, g, r = cv2.split(img)

# %%
img = cv2.merge((g, r, b))
status = cv2.imwrite(r'sample2.jpeg',  img)

# %% [markdown]
# Making the frame for image

# %%
import matplotlib.pyplot as plt

# %%
BLUE = [255, 0, 0]
img = cv2.imread(r'Sample1.jpg',1)
replicate = cv2.copyMakeBorder(img, 10, 10, 10, 10, cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img, 10, 10, 10, 10, cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img, 10, 10, 10, 10, cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img, 10, 10, 10, 10, cv2.BORDER_WRAP)
constant = cv2.copyMakeBorder(img, 10, 10, 10, 10, cv2.BORDER_CONSTANT)
plt.subplot(231),plt.imshow(img,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()

# %% [markdown]
# Change in Color Image

# %%
import cv2
img = cv2.imread(r'Sample1.jpg',1)
window_name = 'Image'
image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
status = cv2.imwrite(r'sample1_greyscale.jpeg',  image)

# %% [markdown]
# Reading the image

# %%
img = cv2.imread(r'Sample1.jpg',1)
scale = 60
width = int(img.shape[1]*scale/100)
height = int(img.shape[0]*scale/100)
dim = (width,height)
print(f"Original Dimension: {img.shape}")
#resize the image
resized = cv2.resize(img,dim)
print(f"Resized Dimension: {resized.shape}")
cv2.imwrite('sample1_resized.jpeg',resized)
# Out:
# Original Dimension: (1080, 1920, 3)
# Resized Dimension: (648, 1152, 3)
# True
